# %%
"""

1.14 (Research: The Ethics of Deep Fakes) Artificial-intelligence technologies are making it possible to create deep 
fakes—realistic fake videos of people that capture their appear￾ance, voice, body motions and facial expressions. You can have
them say and do whatever you specify. Research the ethics of deep fakes. What would happen if you turned on your TV and saw a 
deep-fake video of a prominent government official or newscaster reporting that a nuclear attack was about to happen? Research
Orson Welles and his “War of the Worlds” radio broadcast of 1938, which created mass panic.

"""

# %%
"""

Deep fakes are AI-generated videos or audio that convincingly mimic real people, making it possible to create realistic but
false content.

Ethical concerns:
1) Misinformation: Spreading false news or propaganda.
2) Fraud and manipulation: Identity theft, financial scams, political influence.
3) Privacy violations: Using someone’s likeness without consent.
4) Erosion of trust: Undermining confidence in media and public figures.

Potential consequences:
If a deep fake showed a government official announcing a nuclear attack, it could cause mass panic, economic disruption, or 
even international conflict, similar to the 1938 “War of the Worlds” radio broadcast by Orson Welles, which caused real-world
fear because listeners believed the fictional alien invasion was true.

Lesson: Deep fakes magnify the risks of misinformation and make ethical regulation, verification, and media literacy critically
important.

"""
