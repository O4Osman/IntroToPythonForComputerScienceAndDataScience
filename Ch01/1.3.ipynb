# %%
"""

1.3 (Creating a Jupyter Notebook) Using the techniques you learned in Section 1.10.3,
create a Jupyter Notebook containing cells for the previous exercise’s expressions and exe￾cute those expressions.

"""

# %%
# Already done.
