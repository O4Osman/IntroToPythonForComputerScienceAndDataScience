# %%
"""

1.8 (Research: Reproducibility) A crucial concept in data-science studies is reproduc￾ibility, which helps others (and you) 
reproduce your results. Research reproducibility and list the concepts used to create reproducible results in data-science 
studies. Research and discuss the part that Jupyter Notebooks play in reproducibility.

"""

# %%
"""

Reproducibility in data science is the ability to repeat an analysis and get the same results using the same data, code, and 
methods. It ensures transparency, reliability, and collaboration.

Key concepts to achieve reproducibility:
1) Version control (e.g., Git) to track code changes.
2) Environment management (e.g., conda, Docker) to fix software dependencies.
3) Data management to store raw data and document transformations.
4) Randomness control (setting seeds) for consistent results.
5) Clear documentation and modular scripts to automate workflows.

Jupyter Notebooks help reproducibility by combining code, explanations, and visualizations in one document. Best practices 
include running cells top-to-bottom, documenting steps, fixing random seeds, and sharing environment details. They make 
analysis transparent and easier to replicate but require careful execution to avoid hidden state issues.

"""
