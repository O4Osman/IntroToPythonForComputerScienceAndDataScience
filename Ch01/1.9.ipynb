# %%
"""

1.9 (Research: Artificial General Intelligence) One of the most ambitious goals in the
field of AI is to achieve artificial general intelligence—the point at which machine intelligence would equal human 
intelligence. Research this intriguing topic. When is this fore￾cast to happen? What are some key ethical issues this raises? 
Human intelligence seems to be stable over long periods. Powerful computers with artificial general intelligence could
conceivably (and quickly) evolve intelligence far beyond that of humans. Research and dis￾cuss the issues this raises. 

"""

# %%
"""

Artificial General Intelligence (AGI) refers to AI that can perform any intellectual task a human can, with reasoning, 
learning, and problem-solving across domains.

Forecast: Estimates vary widely—some experts predict AGI could emerge by 2040–2060, though there is high uncertainty.

Key ethical issues:
1) Control and safety: AGI could surpass human intelligence, making its actions unpredictable.
2) Job displacement: Widespread automation could disrupt economies.
3) Decision-making power: AGI could influence politics, law, and social systems.
4) Existential risk: Superintelligent AI could act in ways that threaten humanity if misaligned with human values.

Implications: Unlike human intelligence, AGI could self-improve rapidly, potentially evolving far beyond human cognitive 
abilities. This raises urgent concerns about regulation, value alignment, and long-term safety.

"""
