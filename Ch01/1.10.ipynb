# %%
"""

1.10 (Research: Intelligent Assistants) Many companies now offer computerized intelli￾gent assistants, such as IBM Watson, 
Amazon Alexa, Apple Siri, Google Assistant and Mi￾crosoft Cortana. Research these and others and list uses that can improve 
people’s lives. Research privacy and ethics issues for intelligent assistants. Locate amusing intelligent￾assistant anecdotes.

"""

# %%
"""

Intelligent Assistants like IBM Watson, Amazon Alexa, Apple Siri, Google Assistant, and Microsoft Cortana help improve daily 
life by:
1) Productivity: Setting reminders, managing calendars, sending messages.
2) Information access: Answering questions, providing news, weather, and directions.
3) Smart home control: Operating lights, thermostats, and appliances.
4) Health support: Tracking fitness, providing medical information, medication reminders.
5) Entertainment: Playing music, audiobooks, or games.

Privacy & ethics issues:
1) Constant listening can capture sensitive conversations.
2) Data storage and sharing may be exploited by companies or hackers.
3) Bias in AI responses or decision-making.
4) Consent: Users may unknowingly provide personal data.

Amusing anecdotes:
1) Alexa once ordered pizza on its own after mishearing a conversation.
2) Siri has been known to give funny or sarcastic responses to unusual questions.
3) Google Assistant has occasionally had unexpected conversations with other smart devices, creating humorous interactions.

"""
