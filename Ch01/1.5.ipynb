# %%
"""

1.5 (Clock as an Object) Clocks are among the world’s most common objects. Discuss how each of the following terms and 
concepts applies to the notion of a clock: class, object, instantiation, instance variable, reuse, method, inheritance 
(consider, for example, an alarm clock), superclass, subclass.

"""

# %%
"""
class:
    A class is a blueprint from which we can create objects. For example class Clock which contain methods and properties of 
    clock. Example of properties are clock time and color of clock. Examples of methods are increase time and time correction.

object:
    Object is an instance of a class. object of class clock will have properties and methods which are defined inside the class
    . Using this object we can set those properties and call those methods.

instantiation:
    Instantiation is the process of creating an object of a class. if we want to use methods and properties of clock class we 
    need to instantiate an object of clock class.

instance variable:
    Instance variables are properties that belong to an object. For example color = red.

reuse:
    Reuse means using same class or methods in another class or program. we can reuse methods and perperties of this clock
    class in another class using inheritance.

method:
    Method is a function defined inside the class. Method is a task that clock can perfrom. For example move the time or reset
    the time.

inheritance:
    Inheritance allow a class to use methods and properties of another class. we can use inheritance to reuse methods and 
    propertie of this class into an alarm clock class which have some aditional purpose. In this case clock is base class and
    alarm clock is child class.

"""
