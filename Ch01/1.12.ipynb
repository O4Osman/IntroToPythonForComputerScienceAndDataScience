# %%
"""

1.12 (Research: Big Data, AI and the Cloud—How Companies Use These Technologies)
For a major organization of your choice, research how they may be using each of the fol￾lowing technologies that you’ll use in
this book: Python, AI, big data, the cloud, mobile, natural language processing, speech recognition, speech synthesis, 
database, machine learning, deep learning, reinforcement learning, Hadoop, Spark, Internet of Things (IoT) and web services.

"""

# %%
"""

Company: Amazon
1) Python: Backend services, data analysis, AI model development.
2) AI & Machine Learning: Product recommendations, fraud detection, Amazon Go stores.
3) Deep Learning: Computer vision for warehouse robots, Alexa voice understanding.
4) Reinforcement Learning: Optimizing warehouse logistics and delivery routes.
5) Big Data & Hadoop/Spark: Analyzing customer behavior, sales trends, and inventory.
6) Cloud (AWS): Provides scalable infrastructure, storage, AI/ML services.
7) Mobile: Shopping app, Alexa app, Prime Video.
8) Natural Language Processing & Speech Recognition: Alexa voice commands, customer support chatbots.
9) Speech Synthesis: Alexa responses, Kindle text-to-speech.
10) Database: Amazon RDS, DynamoDB for structured/unstructured data.
11) IoT: Smart devices like Echo, smart home integrations.
12) Web Services: AWS APIs, Alexa Skills, Amazon web applications.

Amazon integrates these technologies to enhance customer experience, optimize operations, and provide scalable cloud solutions.

"""
