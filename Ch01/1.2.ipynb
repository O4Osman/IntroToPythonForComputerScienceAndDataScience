# %%
"""

1.2 (IPython Session) Using the techniques you learned in Section 1.10.1, execute the following expressions. Which, if any,
produce a runtime error? 
a) 10 / 3 + 7
b) 10 // 3 + 7
c) 10 / (3 + 7)
d) 10 / 3 - 3
e) 10 / (3 - 3)
f) 10 // (3 - 3)

"""

# %%
# a
10 / 3 + 7
# Out:
# 10.333333333333334

# %%
# b) 
10 // 3 + 7
# Out:
# 10

# %%
# c) 
10 / (3 + 7)
# Out:
# 1.0

# %%
# d) 
10 / 3 - 3
# Out:
# 0.3333333333333335

# %%
# e) 
10 / (3 - 3)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # e)
# ----> 2 10 / (3 - 3)
#
# ZeroDivisionError: division by zero

# %%
# f) 
10 // (3 - 3)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # f)
# ----> 2 10 // (3 - 3)
#
# ZeroDivisionError: integer division or modulo by zero

# %%
# task e & f produced run time errors.
