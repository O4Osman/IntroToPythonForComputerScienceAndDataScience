# %%
"""

1.17 (OWASP Python Security Project) Building secure computer applications is a tre￾mendous challenge. Many of the world’s 
largest companies, government agencies, and military organizations have had their systems compromised. The OWASP project is 
concerned with "hardening" computer systems and applications to resist attacks. Research OWASP and discuss their 
accomplishments and current challenges.

"""

# %%
"""

OWASP (Open Worldwide Application Security Project) is a nonprofit organization focused on improving application security 
through open-source guidance, tools, and standards.

Key Accomplishments:
OWASP Top 10: The most widely adopted list of critical web application security risks, used globally as a security baseline.
Open-source tools: Tools like OWASP ZAP, WebGoat, and Dependency-Check help developers and security teams test and learn 
secure coding.
Security standards: Frameworks such as ASVS and SAMM help organizations measure and mature their application security practices.
Global awareness: OWASP chapters, conferences, and free documentation have significantly improved security awareness among 
developers.

Current Challenges
Rapidly evolving threats: APIs, cloud, supply-chain attacks, and AI/LLMs require constant updates to guidance.
Poor practical adoption: Many teams know OWASP Top 10 but don’t fully integrate it into the SDLC (DevSecOps).
Volunteer dependency: Some projects suffer from slow updates due to limited contributors.
System complexity: Modern microservices and third-party dependencies make security harder to manage and document.

"""
