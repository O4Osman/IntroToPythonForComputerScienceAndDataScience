# %%
"""

1.19 (Research: Mobile App Development with Python) Research the tools that are avail￾able for Python-based iOS and Android 
app development, such as BeeWare, Kivy, Py-Mob, Pythonista and others. Which of these are cross-platform? Mobile applications
development is one of the fastest growing areas of software development, and it’s a great source of class projects, directed 
study projects, capstone exercise projects and even thesis projects. With cross-platform app-development tools, you’ll be able
to write your own apps and deploy them on many app stores quickly.

"""

# %%
"""

Python supports mobile app development through several frameworks targeting Android and iOS.

BeeWare – Cross-platform
Builds native apps using a single Python codebase. Supports Android, iOS, Windows, macOS, and Linux.

Kivy – Cross-platform
Open-source framework with its own UI layer. Supports Android, iOS, Windows, and Linux. Commonly used for prototypes and 
interactive apps.

Py-Mob – Limited support
Experimental tool with a small ecosystem; not widely used in production.

Pythonista – iOS only
Python development environment for iOS, mainly for learning and scripting. Limited App Store deployment.

Chaquopy – Android only
Integrates Python with native Android (Java/Kotlin) apps.

"""
