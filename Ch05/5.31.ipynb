# %%
"""

5.31 (Intro to Data Science: Coin Tossing) Modify the die-rolling simulation in Section 5.17.2 to simulate the flipping a 
coin. Use randomly generated 1s and 2s to represent heads and tails, respectively. Initially, do not include the frequencies 
and percentages above the bars. Then modify your code to include the frequencies and percentages. Run simulations for 
200, 20,000 and 200,000 coin flips. Do you get approximately 50% heads and 50% tails? Do you see the “law of large numbers"
in operation here?

"""

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import seaborn as sns

# %%
# Flipping Coin 200 times
coin_flips = [random.randrange(1, 3) for i in range(200)]
values, frequencies = np.unique(coin_flips, return_counts=True)
title = f'Flipping a coin {len(coin_flips):,} Times'
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette='bright', hue=values)
axes.set_title(title)
axes.set(xlabel='Coin Faces (1=Head, 2=Tail)', ylabel='Frequency')
axes.set_ylim(top=max(frequencies) * 1.10)
# Out:
# (0.0, 126.50000000000001)

# %%
# Flipping Coin 20000 times
coin_flips = [random.randrange(1, 3) for i in range(20000)]
values, frequencies = np.unique(coin_flips, return_counts=True)
title = f'Flipping a coin {len(coin_flips):,} Times'
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette='bright', hue=values)
axes.set_title(title)
axes.set(xlabel='Coin Faces (1=Head, 2=Tail)', ylabel='Frequency')
axes.set_ylim(top=max(frequencies) * 1.10)
# Out:
# (0.0, 11096.800000000001)

# %%
# Flipping Coin 200000 times
coin_flips = [random.randrange(1, 3) for i in range(200000)]
values, frequencies = np.unique(coin_flips, return_counts=True)
title = f'Flipping a coin {len(coin_flips):,} Times'
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette='bright', hue=values)
axes.set_title(title)
axes.set(xlabel='Coin Faces (1=Head, 2=Tail)', ylabel='Frequency')
axes.set_ylim(top=max(frequencies) * 1.10)
# Out:
# (0.0, 110156.20000000001)

# %%
# Flipping Coin 200 times with frequency and percentage
coin_flips = [random.randrange(1, 3) for i in range(200)]
values, frequencies = np.unique(coin_flips, return_counts=True)
title = f'Flipping a coin {len(coin_flips):,} Times'
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette='bright', hue=values)
axes.set_title(title)
axes.set(xlabel='Coin Faces (1=Head, 2=Tail)', ylabel='Frequency')
axes.set_ylim(top=max(frequencies) * 1.10)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0
    text_y = bar.get_height()
    text = f'{frequency:,}\n{frequency / len(coin_flips):.3%}'
    axes.text(text_x, text_y, text, fontsize=11, ha='center', va='bottom')

# %%
# Flipping Coin 20000 times with frequency and percentage
coin_flips = [random.randrange(1, 3) for i in range(20000)]
values, frequencies = np.unique(coin_flips, return_counts=True)
title = f'Flipping a coin {len(coin_flips):,} Times'
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette='bright', hue=values)
axes.set_title(title)
axes.set(xlabel='Coin Faces (1=Head, 2=Tail)', ylabel='Frequency')
axes.set_ylim(top=max(frequencies) * 1.10)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0
    text_y = bar.get_height()
    text = f'{frequency:,}\n{frequency / len(coin_flips):.3%}'
    axes.text(text_x, text_y, text, fontsize=11, ha='center', va='bottom')

# %%
# Flipping Coin 200000 times with frequency and percentage
coin_flips = [random.randrange(1, 3) for i in range(200000)]
values, frequencies = np.unique(coin_flips, return_counts=True)
title = f'Flipping a coin {len(coin_flips):,} Times'
sns.set_style('whitegrid')
axes = sns.barplot(x=values, y=frequencies, palette='bright', hue=values)
axes.set_title(title)
axes.set(xlabel='Coin Faces (1=Head, 2=Tail)', ylabel='Frequency')
axes.set_ylim(top=max(frequencies) * 1.10)
for bar, frequency in zip(axes.patches, frequencies):
    text_x = bar.get_x() + bar.get_width() / 2.0
    text_y = bar.get_height()
    text = f'{frequency:,}\n{frequency / len(coin_flips):.3%}'
    axes.text(text_x, text_y, text, fontsize=11, ha='center', va='bottom')

# %%
"""

No I did't get approximately 50% heads and 50% tails. And yes I saw the law of large numbers.
Because as I increased the coin flips the difference between the two decreased.

"""
