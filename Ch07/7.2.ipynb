# %%
"""

7.2 (Broadcasting) Use arange to create a 2-by-2 array containing the numbers 0–3. Use broadcasting to perform each of the 
following operations on the original array:

a) Cube every element of the array.
b) Add 7 to every element of the array.
c) Multiply every element of the array by 2.

"""

# %%
import numpy as np

# %%
arr = np.arange(0, 4).reshape(2, 2)

# %%
arr
# Out:
# array([[0, 1],
#        [2, 3]])

# %%
# a) Cube every element of the array.
cube = arr ** 3

# %%
cube
# Out:
# array([[ 0,  1],
#        [ 8, 27]])

# %%
# b) Add 7 to every element of the array.
add = arr + 7

# %%
add
# Out:
# array([[ 7,  8],
#        [ 9, 10]])

# %%
# c) Multiply every element of the array by 2.
multiply = arr * 2

# %%
multiply
# Out:
# array([[0, 2],
#        [4, 6]])
