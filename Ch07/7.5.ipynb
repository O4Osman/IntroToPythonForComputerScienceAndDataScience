# %%
"""

7.5 (Flattening arrays with flatten vs. ravel) Create a 2-by-3 array containing the first six powers of 2 beginning with 2^0. 
Flatten the array first with method flatten, then with ravel. In each case, display the result then display the original 
array to show that it was unmodified.

"""

# %%
import numpy as np

# %%
arr = (2 ** np.arange(6)).reshape(2, 3)

# %%
arr
# Out:
# array([[ 1,  2,  4],
#        [ 8, 16, 32]])

# %%
flatten = arr.flatten()

# %%
flatten
# Out:
# array([ 1,  2,  4,  8, 16, 32])

# %%
arr
# Out:
# array([[ 1,  2,  4],
#        [ 8, 16, 32]])

# %%
ravel = arr.ravel()

# %%
ravel
# Out:
# array([ 1,  2,  4,  8, 16, 32])

# %%
arr
# Out:
# array([[ 1,  2,  4],
#        [ 8, 16, 32]])
