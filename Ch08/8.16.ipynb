# %%
"""

8.16 (Regular Expressions: Locating URLs) Use a regular expression to search through a string and to locate all valid URLs. 
For this exercise, assume that a valid URL has the form http://www.domain_name.extension, where extension must be two or more 
characters.

"""

# %%
import re

# %%
urls = """
Here are some links:
http://www.google.com
http://www.example.org
http://shop.example.org
http://shop.example-1.org
Visit our page at http://www.mysite.co
This one is invalid: http://www.fake
Another valid one: http://www.university.edu
Broken URL: http://www.website.c
Check this: http://www.shop.pk
Random text without URL.
"""

# %%
results = re.findall(r'http:\/\/\w+\.[\w-]+\.[a-zA-Z]{2,}', urls)

# %%
for result in results:
    print(result)
# Out:
# http://www.google.com
# http://www.example.org
# http://shop.example.org
# http://shop.example-1.org
# http://www.mysite.co
# http://www.university.edu
# http://www.shop.pk
