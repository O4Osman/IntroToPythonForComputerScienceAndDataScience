# %%
"""

8.6 (Tokenizing and Comparing Strings) Write a script that reads a line of text, to- kenizes it using space characters as 
delimiters and outputs only those words ending with the letters 'ed'.

"""

# %%
while True:
    user_in = input('Enter a line: ')
    if len(user_in) > 0:
        break
    else:
        print('Invalid input.')
# Out:
# Enter a line:  my parents named me hameED and my frieds called my humi

# %%
words = user_in.split()

# %%
ed_words = [word for word in words if word.lower().endswith('ed')]

# %%
for w in ed_words:
    print(w)
# Out:
# named
# hameED
# called
