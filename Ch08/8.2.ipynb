# %%
"""

8.2 (Random Sentences) Write a script that uses random-number generation to com- pose sentences. Use four arrays of strings 
called article, noun, verb and preposition. Create a sentence by selecting a word at random from each array in the following 
order: article, noun, verb, preposition, article and noun. As each word is picked, concatenate it to the previous words in 
the sentence. Spaces should separate the words. When the final sentence is output, it should start with a capital letter and 
end with a period. The script should generate and display 20 sentences.

"""

# %%
import random

# %%
article = ["the", "a", "one", "some", "any", "that", "this", "those", "these", "each"]

noun = [
    "boy", "girl", "dog", "town", "car", "teacher", "student", "river", "mountain",
    "computer", "phone", "game", "book", "bird", "child", "city", "road", "store",
    "doctor", "friend"
]

verb = [
    "drove", "jumped", "ran", "walked", "skipped", "talked", "studied", "played",
    "slept", "read", "ate", "wrote", "sang", "listened", "watched", "laughed",
    "built", "painted", "learned", "helped"
]

preposition = [
    "to", "from", "over", "under", "on", "with", "without", "before", "after",
    "around", "through", "between", "into", "across", "behind", "beside",
    "beyond", "near", "above", "below"
]

# %%
pattern  = ['article', 'noun', 'verb', 'preposition', 'article', 'noun']

# %%
for i in range(20):
    sentence = ''
    s_article = random.randrange(0, len(article))
    sentence += article[s_article] + ' '
    s_noun = random.randrange(0, len(noun))
    sentence += noun[s_noun] + ' '
    s_verb = random.randrange(0, len(verb))
    sentence += verb[s_verb] + ' '
    s_preposition = random.randrange(0, len(preposition))
    sentence += preposition[s_preposition] + ' '
    s_article_1 = random.randrange(0, len(article))
    sentence += article[s_article_1] + ' '
    s_noun_1 = random.randrange(0, len(noun))
    sentence += noun[s_noun_1] + '.'
    correct_sentence = sentence.capitalize()
    print(f'{i+1}: {correct_sentence}')
# Out:
# 1: The book watched above the game.
# 2: This bird wrote around each book.
# 3: This student drove around that road.
# 4: Those store helped after each mountain.
# 5: A city read behind this bird.
# 6: The student painted over each mountain.
# 7: Some child studied behind this dog.
# 8: The phone sang from the river.
# 9: The book talked beside these city.
# 10: One boy learned around that dog.
# 11: A store sang behind each city.
# 12: Each teacher watched beside one mountain.
# 13: Those car talked below each car.
# 14: Those child ran before a boy.
# 15: Any town wrote on a town.
# 16: The student read under those boy.
# 17: Any river built above some city.
# 18: Those boy laughed around each river.
# 19: Any river studied into these road.
# 20: The game ran under those friend.
