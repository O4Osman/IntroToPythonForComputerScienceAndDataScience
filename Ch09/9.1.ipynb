# %%
"""

9.1 (Class Average: Writing Grades to a Plain Text File) Figure 3.2 presented a class-average script in which you could enter any number of grades followed by a sentinel value, then 
calculate the class average. Another approach would be to read the grades from a file. In an IPython session, write code that enables you to store any number of grades into a grades.txt 
plain text file.

"""

# %%
import os

# %%
# fig03_02.py
"""Class average program with sentinel-controlled iteration."""

with open('grades.txt', 'w') as grades:
    try:
        grade = input('Enter grade, -1 to end: ')  # get one grade
        while int(grade) != -1:
            grades.write(grade + '\n')
            grade = input('Enter grade, -1 to end: ')
    except ValueError:
        print('Invalid Number.')
# Out:
# Enter grade, -1 to end:  50
# Enter grade, -1 to end:  60
# Enter grade, -1 to end:  70
# Enter grade, -1 to end:  80
# Enter grade, -1 to end:  90
# Enter grade, -1 to end:  999
# Enter grade, -1 to end:  -1
