# %%
"""

9.18 (Project: Anscombe’s Quartet CSV) Locate a CSV file online containing the data for Anscombe’s Quartet. Load the data into 
a pandas DataFrame. Investigate pandas built-in scatter-plot capability for plotting x-y coordinate pairs and use it to plot 
the x-y coordi￾nate pairs in Anscombe’s Quartet.

"""

# %%
import pandas as pd

# %%
df = pd.read_csv('anscombe_quartet.csv', index_col=0)

# %%
df.head()
# Out:
#              dataset   x     y
# rownames
# 1         (1) Linear  10  8.04
# 2         (1) Linear   8  6.95
# 3         (1) Linear  13  7.58
# 4         (1) Linear   9  8.81
# 5         (1) Linear  11  8.33

# %%
df.tail()
# Out:
#                dataset   x      y
# rownames
# 40        (4) Leverage   8   5.25
# 41        (4) Leverage  19  12.50
# 42        (4) Leverage   8   5.56
# 43        (4) Leverage   8   7.91
# 44        (4) Leverage   8   6.89

# %%
df.plot.scatter(x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>
