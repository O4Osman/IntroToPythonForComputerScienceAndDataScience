# %%
"""

6.17 (Project: Cooking with Healthier Ingredients) In the “Strings: A Deeper Look” chapter’s exercises, you’ll write a 
script that enables its user to enter ingredients from a cooking recipe, then recommends healthier replacements. 
In preparation for that exercise, create a dictionary that maps ingredients to lists of potential replacements. 
Some ingredient replacements are shown below:

/6.17.png

Your dictionary should take into consideration that replacements are not always one-for-one. For example, if a cake recipe 
calls for three eggs, it might reasonably use six egg whites instead. Research conversion data for measurements and 
ingredient substitutes online. Your dictionary should map the ingredients to lists of potential substitutes.

"""

# %%
# ingredient_substitutes = {'cup sour cream': [[[1],['cup yogurt']]], 
#                           'cup milk': [[[1/2, 1/2],['cup evaporated milk', 'cup water']],[[1],['cup soy milk']]],
#                           'teaspoon lemon juice': [[[1/2],['teaspoon vinegar']]],
#                           'cup sugar': [[[1/2],['cup honey']],[[1],['cup molasses']],[[1/4],['cup agave nectar']]],
#                           'cup butter': [[[1],['cup margarine']],[[1],['cup yogurt']]],
#                           'cup flour': [[[1],['cup rye']],[[1],['cup rice flour']]],
#                           'cup mayonnaise': [[[1],['cup cottage cheese']]],
#                           'egg': [[[2],['tablespoons cornstarch']],[[2],['tablespoons arrowroot floor']],[[2],['tablespoons potato starch']],
#                                  [[2],['egg whites']],[[1/2],['of a large banana (mashed)']]],
#                           'cup oil': [[[1],['cup applesauce']]]
# }


ingredient_substitutes = {'cup sour cream': [
                                {
                                    'components': [
                                        {'amount': 1, 'ingredient': 'cup yogurt'}
                                    ]
                                }
                            ], 
                          'cup milk': [
                              {
                                  'components': [
                                      {'amount': 1/2, 'ingredient': 'cup evaporated milk'},
                                      {'amount': 1/2, 'ingredient': 'cup water'}
                                  ]
                              },
                              {
                                  'components': [
                                      {'amount': 1, 'ingredient': 'cup soy milk'}
                                  ]
                              }
                          ],
                          'teaspoon lemon juice': [
                              {
                                 'components': [
                                        {'amount': 1/2, 'ingredient': 'teaspoon vinegar'}
                                    ] 
                              }
                          ],
                          'cup sugar': [
                              {
                                 'components': [
                                        {'amount': 1/2, 'ingredient': 'cup honey'}
                                    ] 
                              },
                              {
                                 'components': [
                                        {'amount': 1, 'ingredient': 'cup molasses'}
                                    ] 
                              },
                              {
                                 'components': [
                                        {'amount': 1/4, 'ingredient': 'cup agave nectar'}
                                    ] 
                              }                                  
                          ],
                          'cup butter': [
                                  {
                                      'components': [
                                          {'amount': 1, 'ingredient': 'cup margarine'}
                                      ]
                                  },
                                 {
                                      'components': [
                                          {'amount': 1, 'ingredient': 'cup yogurt'}
                                      ]                                      
                                  }
                          ],
                          'cup flour': [
                              {
                                  'components': [
                                      {'amount': 1, 'ingredient': 'cup rye'}
                                  ]
                              },
                              {
                                  'components': [
                                      {'amount': 1, 'ingredient': 'cup rice flour'}
                                  ]                                  
                              }
                          ],
                          'cup mayonnaise': [
                              {
                                  'components': [
                                      {'amount': 1, 'ingredient': 'cup cottage cheese'}
                                  ]
                              }
                          ],
                          'egg': [
                              {
                                  'components': [
                                 {'amount': 2, 'ingredient': 'tablespoons cornstarch'} 
                                  ]
                              },
                              {
                                  'components': [
                                 {'amount': 2, 'ingredient': 'tablespoons arrowroot floor'} 
                                  ]
                              },
                              {
                                  'components': [
                                 {'amount': 2, 'ingredient': 'tablespoons potato starch'} 
                                  ]
                              },
                              {
                                  'components': [
                                 {'amount': 2, 'ingredient': 'egg whites'} 
                                  ]
                              },
                              {
                                  'components': [
                                 {'amount': 1/2, 'ingredient': 'of a large banana (mashed)'} 
                                  ]
                              },
                          ],
                          'cup oil': [
                              {
                                  'components': [
                                      {'amount': 1, 'ingredient': 'cup applesauce'} 
                                  ]
                              }
                          ]
}

# %%
def get_user_input():
    """get input from user and return quantity and ingredient from that user input"""
    text = input('Enter Ingredient: ')
    text_list = text.split()
    quantity = float(text_list[0])
    ingredient = ''
    for index, value in enumerate(text_list[1:]):
        ingredient += value
        if index != (len(text_list[1:]) - 1):
            ingredient += ' '
    return quantity, ingredient

# %%
def get_alternative(quantity, ingredient):
    """return alternative ingredients if that is present in dictionary"""
    if ingredient not in ingredient_substitutes:
        return f'No substitutes found for {quantity} {ingredient}'
        
    result = ''
    alternatives_list = ingredient_substitutes[ingredient]
    
    for index, dictionary in enumerate(alternatives_list):
        
        for index1, item in enumerate(dictionary['components']):
            result += f'{item['amount'] * quantity}'
            result += ' ' + item['ingredient']
            if index1 != (len(dictionary['components']) - 1):
                result += ' and '    
                
        if index != (len(alternatives_list) - 1):
            result += ' or '
    return result

# %%
quantity, ingredient = get_user_input()
result = get_alternative(quantity, ingredient)
print(result)
# Out:
# Enter Ingredient:  1 cup oil
# 1.0 cup applesauce
